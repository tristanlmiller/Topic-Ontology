# %%
import pandas as pd
import numpy as np

# %%
import lxml.etree as etree
#from lxml import objectify

# %%
# takes a while
tree = etree.parse('simplewiki-20160701-pages-articles-multistream.xml')

# %%
root = tree.getroot()
#print(root)
#print(root.attrib)
#print(root.tag)
for name, value in root.items():
    print('%s = %r' % (name, value))
# Out:
# {http://www.w3.org/2001/XMLSchema-instance}schemaLocation = 'http://www.mediawiki.org/xml/export-0.10/ http://www.mediawiki.org/xml/export-0.10.xsd'
# version = '0.10'
# {http://www.w3.org/XML/1998/namespace}lang = 'en'

# %%
children = root.getchildren()
print ('number of articles: %i.' % (len(children)-1) )
# Out:
# number of articles: 220583.

# %%
samplearticle = children[1000]
for elem in samplearticle.getchildren():
    nchildren = len(elem.getchildren())
    if nchildren> 0:
        print('%s : %s : has %d children \n' %  (elem.tag ,elem.text , nchildren))
       # print(elem.itertext)
        for elem2 in elem.getchildren():
            print(elem2.tag, ':', elem2.text, '\n*********\n')
    else:
        print('%s : %s ' %  (elem.tag ,elem.text))
# Out:
# {http://www.mediawiki.org/xml/export-0.10/}title : Football
# {http://www.mediawiki.org/xml/export-0.10/}ns : 0
# {http://www.mediawiki.org/xml/export-0.10/}id : 3039
# {http://www.mediawiki.org/xml/export-0.10/}revision : None : has 9 children
#
# {http://www.mediawiki.org/xml/export-0.10/}id : 5429320
# *********
#
# {http://www.mediawiki.org/xml/export-0.10/}parentid : 5429319
# *********
#
# {http://www.mediawiki.org/xml/export-0.10/}timestamp : 2016-06-29T15:06:49Z
# *********
#
# {http://www.mediawiki.org/xml/export-0.10/}contributor : None
# *********
#
# {http://www.mediawiki.org/xml/export-0.10/}minor : None
# *********
#
# {http://www.mediawiki.org/xml/export-0.10/}model : wikitext
# *********
#
# {http://www.mediawiki.org/xml/export-0.10/}format : text/x-wiki
# *********
#
# {http://www.mediawiki.org/xml/export-0.10/}text : {{Sports}}
# [[File:Cristiano Ronaldo and Lionel Messi - Portugal vs Argentina, 9th February 2011.jpg|thumb|Cristiano Ronaldo and Lionel Messi]]
# ...

# %%
column_names = []
for i in range(0,len(root.getchildren()[1000].getchildren())):
    column_names.append(root.getchildren()[1000].getchildren()[i].tag)
colnames = [x[43:] for x in column_names]
print('colnames ', colnames)
frame = pd.DataFrame(columns=colnames)
# Out:
# colnames  ['title', 'ns', 'id', 'revision']

# %%
for j in range(1, 100):
    obj = root[j].getchildren()
    texts = []
    for k in range(0, len(colnames)):
        texts.append(obj[k].text)
        
    row = dict(zip(colnames, texts))
    row_s = pd.Series(row)
    row_s.name = j
    frame = frame.append(row_s)
frame
# Out:
#                               title ns   id revision
# 1                             April  0    1     None
# 2                            August  0    2     None
# 3                               Art  0    6     None
# 4                                 A  0    8     None
# 5                               Air  0    9     None
# 6          Wikipedia:Administrators  4   11     None
# 7   Autonomous communities of Spain  0   12     None
# 8                       Alan Turing  0   13     None
# 9                 Alanis Morissette  0   14     None
# 10                Adobe Illustrator  0   17     None
# 11                        Andouille  0   18     None
# 12                          Farming  0   19     None
# 13                       Arithmetic  0   21     None
# 14                         Addition  0   22     None
# 15                      Albigensian  0   24     None
# 16                        Australia  0   27     None
# 17                 American English  0   28     None
# ...

# %%
s = ' '
for chl in samplearticle.iter():
    print( chl, chl.text)
# Out:
#  None
# Football Football
# 0 0
# 3039 3039
#  None
# 5429320 5429320
# 5429319 5429319
# 2016-06-29T15:06:49Z 2016-06-29T15:06:49Z
#  None
# Macdonald-ross Macdonald-ross
# 68157 68157
#  None
# wikitext wikitext
# text/x-wiki text/x-wiki
# {{Sports}}
# [[File:Cristiano Ronaldo and Lionel Messi - Portugal vs Argentina, 9th February 2011.jpg|thumb|Cristiano Ronaldo and Lionel Messi]]
# '''Football''' is a [[sport]]. The most popular type of football is [[Association football]], which is also named "soccer". Although Football is old it is the most popular sport in the world. Football can also mean [[American football]] (gridiron), [[rugby union]], [[rugby league]], [[Australian Rules Football]], [[Gaelic football]] or [[Canadian football]].
#
# [[File:Football (soccer ball).svg|right|180px|thumb|[[Soccer]]]]
#
# ...

# %%
type( samplearticle.getchildren()[3].getchildren()[7].text )
# Out:
# str

# %%
np.NaN.reshape(4,4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-f5733db04676> in <module>()
# ----> 1 np.NaN.reshape(4,4)
#
# AttributeError: 'float' object has no attribute 'reshape'

# %%
root
# Out:
# '$55sdsfgdfg'

# %%
root[1][3].
# Out:
# []

# %%
z = []
z.append('sdf')

# %%
z.append('zzz')
print(z)
# Out:
# ['sdf', 'zzz']

# %%
root[100][3][8].text
# Out:
# "'''Civics''' is the study of [[government]].  It most often refers to studying government in high school to prepare to be a good [[citizen]].  In college, civics is usually called [[political science]].  Since a [[city]] has the most unsimple government problems, the word for this study is like that for city.\n\nTheories of civics can be grouped as:\n\n*[[Anarchist]]\n*[[Capitalist]]\n*[[Democrats|Democrat]]\n*[[Green Party|Green]]\n*[[Libertarian]]\n*[[Republicans|Republican]]\n\n{{Politics-stub}}\n\n[[Category:Politics]]"
